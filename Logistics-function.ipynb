# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
x = np.linspace(-10, 10, 100)
z = 1 + 2 * x  # Linear combination
y = 1 / (1 + np.exp(-z))  # Logistics function

plt.plot(x, y)
plt.title('Logistics function')
plt.xlabel('x')
plt.ylabel('P(y=1|x)')
plt.show()
